# %% [markdown]
# # Using the ctapipe Provenance service
#
# The provenance functionality is used automatically when you use most of ctapipe functionality (particularly `ctapipe.core.Tool` and functions in `ctapipe.io` and `ctapipe.utils`), so normally you don't have to work with it directly. It tracks both input and output files, as well as details of the machine and software environment on which a Tool executed.
#
# Here we show some very low-level functions of this system:

# %%
from ctapipe.core import Provenance
from pprint import pprint

# %% [markdown]
# ## Activities
#
# The basis of Provenance is an *activity*, which is generally an executable or step in a script. Activities can be nested (e.g. with sub-activities), as shown below, but normally this is not required:

# %%
p = Provenance()  # note this is a singleton, so only ever one global provenence object
p.clear()
p.start_activity()
p.add_input_file("test.txt")

p.start_activity("sub")
p.add_input_file("subinput.txt")
p.add_input_file("anothersubinput.txt")
p.add_output_file("suboutput.txt")
p.finish_activity("sub")

p.start_activity("sub2")
p.add_input_file("sub2input.txt")
p.finish_activity("sub2")

p.finish_activity()

# %%
p.finished_activity_names
# Out:
# ['sub', 'sub2', '/home/travis/virtualenv/python3.8.0/bin/python']

# %% [markdown]
# Activities have associated input and output *entities*  (files or other objects)

# %%
[ (x['activity_name'], x['input']) for x in p.provenance]
# Out:
# [('sub',
#   [{'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/subinput.txt',
#     'role': None},
#    {'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/anothersubinput.txt',
#     'role': None}]),
#  ('sub2',
#   [{'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/sub2input.txt',
#     'role': None}]),
#  ('/home/travis/virtualenv/python3.8.0/bin/python',
#   [{'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/test.txt',
#     'role': None}])]

# %% [markdown]
# Activities track when they were started and finished:

# %%
[ (x['activity_name'],x['duration_min']) for x in p.provenance]
# Out:
# [('sub', 0.00010000000012055921),
#  ('sub2', 0.00010000000012055921),
#  ('/home/travis/virtualenv/python3.8.0/bin/python', 0.004966666666739172)]

# %% [markdown]
# ## Full provenance
#
# The provence object is a list of activitites, and for each lots of details are collected:

# %%
p.provenance[0]
# Out:
# {'activity_name': 'sub',
#  'activity_uuid': '08717f10-501c-4c01-b1a2-807e66c41e35',
#  'start': {'time_utc': '2020-04-13T17:41:22.587'},
#  'stop': {'time_utc': '2020-04-13T17:41:22.593'},
#  'system': {'ctapipe_version': 'unknown',
#   'ctapipe_resources_version': '0.2.19',
#   'pyhessio_version': '2.1.1',
#   'eventio_version': '1.0.1',
#   'ctapipe_svc_path': None,
#   'executable': '/home/travis/virtualenv/python3.8.0/bin/python',
#   'platform': {'architecture_bits': '64bit',
#    'architecture_linkage': 'ELF',
#    'machine': 'x86_64',
#    'processor': 'x86_64',
#    'node': 'travis-job-742a6a54-15f7-4367-9191-9a26e20b992b',
#    'version': '#29~16.04.1-Ubuntu SMP Tue Feb 12 16:31:10 UTC 2019',
#    'system': 'Linux',
#    'release': '4.15.0-1028-gcp',
#    'libcver': ('glibc', '2.23'),
#    'num_cpus': 2,
#    'boot_time': '2020-04-13T17:33:06.000'},
#   'python': {'version_string': '3.8.0 (default, Oct 15 2019, 17:49:23) \n[GCC 5.4.0 20160609]',
#    'version': ('3', '8', '0'),
#    'compiler': 'GCC 5.4.0 20160609',
#    'implementation': 'CPython'},
#   'environment': {'CONDA_DEFAULT_ENV': None,
#    'CONDA_PREFIX': None,
#    'CONDA_PYTHON_EXE': None,
#    'CONDA_EXE': None,
#    'CONDA_PROMPT_MODIFIER': None,
#    'CONDA_SHLVL': None,
#    'PATH': '/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin',
#    'LD_LIBRARY_PATH': None,
#    'DYLD_LIBRARY_PATH': None,
#    'USER': 'travis',
#    'HOME': '/home/travis',
#    'SHELL': '/bin/bash'},
#   'arguments': ['/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py',
#    '-f',
#    '/tmp/tmpy5h1s3fj.json',
#    '--HistoryManager.hist_file=:memory:'],
#   'start_time_utc': '2020-04-13T17:41:22.593'},
#  'input': [{'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/subinput.txt',
#    'role': None},
#   {'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/anothersubinput.txt',
#    'role': None}],
#  'output': [{'url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/suboutput.txt',
#    'role': None}],
#  'status': 'sub',
#  'duration_min': 0.00010000000012055921}

# %% [markdown]
# This can be better represented in JSON:

# %%
print(p.as_json(indent=2))
# Out:
# [
#   {
#     "activity_name": "sub",
#     "activity_uuid": "08717f10-501c-4c01-b1a2-807e66c41e35",
#     "start": {
#       "time_utc": "2020-04-13T17:41:22.587"
#     },
#     "stop": {
#       "time_utc": "2020-04-13T17:41:22.593"
#     },
#     "system": {
#       "ctapipe_version": "unknown",
#       "ctapipe_resources_version": "0.2.19",
#       "pyhessio_version": "2.1.1",
#       "eventio_version": "1.0.1",
#       "ctapipe_svc_path": null,
#       "executable": "/home/travis/virtualenv/python3.8.0/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "ELF",
#         "machine": "x86_64",
#         "processor": "x86_64",
#         "node": "travis-job-742a6a54-15f7-4367-9191-9a26e20b992b",
#         "version": "#29~16.04.1-Ubuntu SMP Tue Feb 12 16:31:10 UTC 2019",
#         "system": "Linux",
#         "release": "4.15.0-1028-gcp",
#         "libcver": [
#           "glibc",
#           "2.23"
#         ],
#         "num_cpus": 2,
#         "boot_time": "2020-04-13T17:33:06.000"
#       },
#       "python": {
#         "version_string": "3.8.0 (default, Oct 15 2019, 17:49:23) \n[GCC 5.4.0 20160609]",
#         "version": [
#           "3",
#           "8",
#           "0"
#         ],
#         "compiler": "GCC 5.4.0 20160609",
#         "implementation": "CPython"
#       },
#       "environment": {
#         "CONDA_DEFAULT_ENV": null,
#         "CONDA_PREFIX": null,
#         "CONDA_PYTHON_EXE": null,
#         "CONDA_EXE": null,
#         "CONDA_PROMPT_MODIFIER": null,
#         "CONDA_SHLVL": null,
#         "PATH": "/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin",
#         "LD_LIBRARY_PATH": null,
#         "DYLD_LIBRARY_PATH": null,
#         "USER": "travis",
#         "HOME": "/home/travis",
#         "SHELL": "/bin/bash"
#       },
#       "arguments": [
#         "/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py",
#         "-f",
#         "/tmp/tmpy5h1s3fj.json",
#         "--HistoryManager.hist_file=:memory:"
#       ],
#       "start_time_utc": "2020-04-13T17:41:22.593"
#     },
#     "input": [
#       {
#         "url": "/home/travis/build/cta-observatory/ctapipe/docs/examples/subinput.txt",
#         "role": null
#       },
#       {
#         "url": "/home/travis/build/cta-observatory/ctapipe/docs/examples/anothersubinput.txt",
#         "role": null
#       }
#     ],
#     "output": [
#       {
#         "url": "/home/travis/build/cta-observatory/ctapipe/docs/examples/suboutput.txt",
#         "role": null
#       }
#     ],
#     "status": "sub",
#     "duration_min": 0.00010000000012055921
#   },
#   {
#     "activity_name": "sub2",
#     "activity_uuid": "b2f160c3-4333-41cc-972d-cdfa4ca88934",
#     "start": {
#       "time_utc": "2020-04-13T17:41:22.595"
#     },
#     "stop": {
#       "time_utc": "2020-04-13T17:41:22.601"
#     },
#     "system": {
#       "ctapipe_version": "unknown",
#       "ctapipe_resources_version": "0.2.19",
#       "pyhessio_version": "2.1.1",
#       "eventio_version": "1.0.1",
#       "ctapipe_svc_path": null,
#       "executable": "/home/travis/virtualenv/python3.8.0/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "ELF",
#         "machine": "x86_64",
#         "processor": "x86_64",
#         "node": "travis-job-742a6a54-15f7-4367-9191-9a26e20b992b",
#         "version": "#29~16.04.1-Ubuntu SMP Tue Feb 12 16:31:10 UTC 2019",
#         "system": "Linux",
#         "release": "4.15.0-1028-gcp",
#         "libcver": [
#           "glibc",
#           "2.23"
#         ],
#         "num_cpus": 2,
#         "boot_time": "2020-04-13T17:33:06.000"
#       },
#       "python": {
#         "version_string": "3.8.0 (default, Oct 15 2019, 17:49:23) \n[GCC 5.4.0 20160609]",
#         "version": [
#           "3",
#           "8",
#           "0"
#         ],
#         "compiler": "GCC 5.4.0 20160609",
#         "implementation": "CPython"
#       },
#       "environment": {
#         "CONDA_DEFAULT_ENV": null,
#         "CONDA_PREFIX": null,
#         "CONDA_PYTHON_EXE": null,
#         "CONDA_EXE": null,
#         "CONDA_PROMPT_MODIFIER": null,
#         "CONDA_SHLVL": null,
#         "PATH": "/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin",
#         "LD_LIBRARY_PATH": null,
#         "DYLD_LIBRARY_PATH": null,
#         "USER": "travis",
#         "HOME": "/home/travis",
#         "SHELL": "/bin/bash"
#       },
#       "arguments": [
#         "/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py",
#         "-f",
#         "/tmp/tmpy5h1s3fj.json",
#         "--HistoryManager.hist_file=:memory:"
#       ],
#       "start_time_utc": "2020-04-13T17:41:22.601"
#     },
#     "input": [
#       {
#         "url": "/home/travis/build/cta-observatory/ctapipe/docs/examples/sub2input.txt",
#         "role": null
#       }
#     ],
#     "output": [],
#     "status": "sub2",
#     "duration_min": 0.00010000000012055921
#   },
#   {
#     "activity_name": "/home/travis/virtualenv/python3.8.0/bin/python",
#     "activity_uuid": "cbf029a7-a4e5-483c-b880-fd8076e46291",
#     "start": {
#       "time_utc": "2020-04-13T17:41:22.304"
#     },
#     "stop": {
#       "time_utc": "2020-04-13T17:41:22.602"
#     },
#     "system": {
#       "ctapipe_version": "unknown",
#       "ctapipe_resources_version": "0.2.19",
#       "pyhessio_version": "2.1.1",
#       "eventio_version": "1.0.1",
#       "ctapipe_svc_path": null,
#       "executable": "/home/travis/virtualenv/python3.8.0/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "ELF",
#         "machine": "x86_64",
#         "processor": "x86_64",
#         "node": "travis-job-742a6a54-15f7-4367-9191-9a26e20b992b",
#         "version": "#29~16.04.1-Ubuntu SMP Tue Feb 12 16:31:10 UTC 2019",
#         "system": "Linux",
#         "release": "4.15.0-1028-gcp",
#         "libcver": [
#           "glibc",
#           "2.23"
#         ],
#         "num_cpus": 2,
#         "boot_time": "2020-04-13T17:33:06.000"
#       },
#       "python": {
#         "version_string": "3.8.0 (default, Oct 15 2019, 17:49:23) \n[GCC 5.4.0 20160609]",
#         "version": [
#           "3",
#           "8",
#           "0"
#         ],
#         "compiler": "GCC 5.4.0 20160609",
#         "implementation": "CPython"
#       },
#       "environment": {
#         "CONDA_DEFAULT_ENV": null,
#         "CONDA_PREFIX": null,
#         "CONDA_PYTHON_EXE": null,
#         "CONDA_EXE": null,
#         "CONDA_PROMPT_MODIFIER": null,
#         "CONDA_SHLVL": null,
#         "PATH": "/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin",
#         "LD_LIBRARY_PATH": null,
#         "DYLD_LIBRARY_PATH": null,
#         "USER": "travis",
#         "HOME": "/home/travis",
#         "SHELL": "/bin/bash"
#       },
#       "arguments": [
#         "/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py",
#         "-f",
#         "/tmp/tmpy5h1s3fj.json",
#         "--HistoryManager.hist_file=:memory:"
#       ],
#       "start_time_utc": "2020-04-13T17:41:22.586"
#     },
#     "input": [
#       {
#         "url": "/home/travis/build/cta-observatory/ctapipe/docs/examples/test.txt",
#         "role": null
#       }
#     ],
#     "output": [],
#     "status": "completed",
#     "duration_min": 0.004966666666739172
#   }
# ]

# %% [markdown]
# ## Storing provenance info in output files
#
# * already this can be stored in something like an HDF5 file header, which allows hierarchies.
# * Try to flatted the data so it can be stored in a key=value header in a **FITS file** (using the FITS extended keyword convention to allow >8 character keywords), or as a table

# %%
def flatten_dict(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
d = dict(activity=p.provenance)

# %%
pprint(flatten_dict(d))
# Out:
# {'activity.0.activity_name': 'sub',
#  'activity.0.activity_uuid': '08717f10-501c-4c01-b1a2-807e66c41e35',
#  'activity.0.duration_min': 0.00010000000012055921,
#  'activity.0.input.0.role': None,
#  'activity.0.input.0.url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/subinput.txt',
#  'activity.0.input.1.role': None,
#  'activity.0.input.1.url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/anothersubinput.txt',
#  'activity.0.output.0.role': None,
#  'activity.0.output.0.url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/suboutput.txt',
#  'activity.0.start.time_utc': '2020-04-13T17:41:22.587',
#  'activity.0.status': 'sub',
#  'activity.0.stop.time_utc': '2020-04-13T17:41:22.593',
#  'activity.0.system.arguments.0': '/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py',
#  'activity.0.system.arguments.1': '-f',
#  'activity.0.system.arguments.2': '/tmp/tmpy5h1s3fj.json',
#  'activity.0.system.arguments.3': '--HistoryManager.hist_file=:memory:',
#  'activity.0.system.ctapipe_resources_version': '0.2.19',
#  'activity.0.system.ctapipe_svc_path': None,
#  'activity.0.system.ctapipe_version': 'unknown',
#  'activity.0.system.environment.CONDA_DEFAULT_ENV': None,
#  'activity.0.system.environment.CONDA_EXE': None,
#  'activity.0.system.environment.CONDA_PREFIX': None,
#  'activity.0.system.environment.CONDA_PROMPT_MODIFIER': None,
#  'activity.0.system.environment.CONDA_PYTHON_EXE': None,
#  'activity.0.system.environment.CONDA_SHLVL': None,
#  'activity.0.system.environment.DYLD_LIBRARY_PATH': None,
#  'activity.0.system.environment.HOME': '/home/travis',
#  'activity.0.system.environment.LD_LIBRARY_PATH': None,
#  'activity.0.system.environment.PATH': '/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin',
#  'activity.0.system.environment.SHELL': '/bin/bash',
#  'activity.0.system.environment.USER': 'travis',
#  'activity.0.system.eventio_version': '1.0.1',
#  'activity.0.system.executable': '/home/travis/virtualenv/python3.8.0/bin/python',
#  'activity.0.system.platform.architecture_bits': '64bit',
#  'activity.0.system.platform.architecture_linkage': 'ELF',
#  'activity.0.system.platform.boot_time': '2020-04-13T17:33:06.000',
#  'activity.0.system.platform.libcver': ('glibc', '2.23'),
#  'activity.0.system.platform.machine': 'x86_64',
#  'activity.0.system.platform.node': 'travis-job-742a6a54-15f7-4367-9191-9a26e20b992b',
#  'activity.0.system.platform.num_cpus': 2,
#  'activity.0.system.platform.processor': 'x86_64',
#  'activity.0.system.platform.release': '4.15.0-1028-gcp',
#  'activity.0.system.platform.system': 'Linux',
#  'activity.0.system.platform.version': '#29~16.04.1-Ubuntu SMP Tue Feb 12 '
#                                        '16:31:10 UTC 2019',
#  'activity.0.system.pyhessio_version': '2.1.1',
#  'activity.0.system.python.compiler': 'GCC 5.4.0 20160609',
#  'activity.0.system.python.implementation': 'CPython',
#  'activity.0.system.python.version': ('3', '8', '0'),
#  'activity.0.system.python.version_string': '3.8.0 (default, Oct 15 2019, '
#                                             '17:49:23) \n'
#                                             '[GCC 5.4.0 20160609]',
#  'activity.0.system.start_time_utc': '2020-04-13T17:41:22.593',
#  'activity.1.activity_name': 'sub2',
#  'activity.1.activity_uuid': 'b2f160c3-4333-41cc-972d-cdfa4ca88934',
#  'activity.1.duration_min': 0.00010000000012055921,
#  'activity.1.input.0.role': None,
#  'activity.1.input.0.url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/sub2input.txt',
#  'activity.1.start.time_utc': '2020-04-13T17:41:22.595',
#  'activity.1.status': 'sub2',
#  'activity.1.stop.time_utc': '2020-04-13T17:41:22.601',
#  'activity.1.system.arguments.0': '/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py',
#  'activity.1.system.arguments.1': '-f',
#  'activity.1.system.arguments.2': '/tmp/tmpy5h1s3fj.json',
#  'activity.1.system.arguments.3': '--HistoryManager.hist_file=:memory:',
#  'activity.1.system.ctapipe_resources_version': '0.2.19',
#  'activity.1.system.ctapipe_svc_path': None,
#  'activity.1.system.ctapipe_version': 'unknown',
#  'activity.1.system.environment.CONDA_DEFAULT_ENV': None,
#  'activity.1.system.environment.CONDA_EXE': None,
#  'activity.1.system.environment.CONDA_PREFIX': None,
#  'activity.1.system.environment.CONDA_PROMPT_MODIFIER': None,
#  'activity.1.system.environment.CONDA_PYTHON_EXE': None,
#  'activity.1.system.environment.CONDA_SHLVL': None,
#  'activity.1.system.environment.DYLD_LIBRARY_PATH': None,
#  'activity.1.system.environment.HOME': '/home/travis',
#  'activity.1.system.environment.LD_LIBRARY_PATH': None,
#  'activity.1.system.environment.PATH': '/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin',
#  'activity.1.system.environment.SHELL': '/bin/bash',
#  'activity.1.system.environment.USER': 'travis',
#  'activity.1.system.eventio_version': '1.0.1',
#  'activity.1.system.executable': '/home/travis/virtualenv/python3.8.0/bin/python',
#  'activity.1.system.platform.architecture_bits': '64bit',
#  'activity.1.system.platform.architecture_linkage': 'ELF',
#  'activity.1.system.platform.boot_time': '2020-04-13T17:33:06.000',
#  'activity.1.system.platform.libcver': ('glibc', '2.23'),
#  'activity.1.system.platform.machine': 'x86_64',
#  'activity.1.system.platform.node': 'travis-job-742a6a54-15f7-4367-9191-9a26e20b992b',
#  'activity.1.system.platform.num_cpus': 2,
#  'activity.1.system.platform.processor': 'x86_64',
#  'activity.1.system.platform.release': '4.15.0-1028-gcp',
#  'activity.1.system.platform.system': 'Linux',
#  'activity.1.system.platform.version': '#29~16.04.1-Ubuntu SMP Tue Feb 12 '
#                                        '16:31:10 UTC 2019',
#  'activity.1.system.pyhessio_version': '2.1.1',
#  'activity.1.system.python.compiler': 'GCC 5.4.0 20160609',
#  'activity.1.system.python.implementation': 'CPython',
#  'activity.1.system.python.version': ('3', '8', '0'),
#  'activity.1.system.python.version_string': '3.8.0 (default, Oct 15 2019, '
#                                             '17:49:23) \n'
#                                             '[GCC 5.4.0 20160609]',
#  'activity.1.system.start_time_utc': '2020-04-13T17:41:22.601',
#  'activity.2.activity_name': '/home/travis/virtualenv/python3.8.0/bin/python',
#  'activity.2.activity_uuid': 'cbf029a7-a4e5-483c-b880-fd8076e46291',
#  'activity.2.duration_min': 0.004966666666739172,
#  'activity.2.input.0.role': None,
#  'activity.2.input.0.url': '/home/travis/build/cta-observatory/ctapipe/docs/examples/test.txt',
#  'activity.2.start.time_utc': '2020-04-13T17:41:22.304',
#  'activity.2.status': 'completed',
#  'activity.2.stop.time_utc': '2020-04-13T17:41:22.602',
#  'activity.2.system.arguments.0': '/home/travis/virtualenv/python3.8.0/lib/python3.8/site-packages/ipykernel_launcher.py',
#  'activity.2.system.arguments.1': '-f',
#  'activity.2.system.arguments.2': '/tmp/tmpy5h1s3fj.json',
#  'activity.2.system.arguments.3': '--HistoryManager.hist_file=:memory:',
#  'activity.2.system.ctapipe_resources_version': '0.2.19',
#  'activity.2.system.ctapipe_svc_path': None,
#  'activity.2.system.ctapipe_version': 'unknown',
#  'activity.2.system.environment.CONDA_DEFAULT_ENV': None,
#  'activity.2.system.environment.CONDA_EXE': None,
#  'activity.2.system.environment.CONDA_PREFIX': None,
#  'activity.2.system.environment.CONDA_PROMPT_MODIFIER': None,
#  'activity.2.system.environment.CONDA_PYTHON_EXE': None,
#  'activity.2.system.environment.CONDA_SHLVL': None,
#  'activity.2.system.environment.DYLD_LIBRARY_PATH': None,
#  'activity.2.system.environment.HOME': '/home/travis',
#  'activity.2.system.environment.LD_LIBRARY_PATH': None,
#  'activity.2.system.environment.PATH': '/home/travis/virtualenv/python3.8.0/bin:/home/travis/bin:/home/travis/.local/bin:/usr/local/lib/jvm/openjdk11/bin:/opt/pyenv/shims:/home/travis/.phpenv/shims:/home/travis/perl5/perlbrew/bin:/home/travis/.nvm/versions/node/v8.12.0/bin:/home/travis/.rvm/gems/ruby-2.5.3/bin:/home/travis/.rvm/gems/ruby-2.5.3@global/bin:/home/travis/.rvm/rubies/ruby-2.5.3/bin:/home/travis/gopath/bin:/home/travis/.gimme/versions/go1.11.1.linux.amd64/bin:/usr/local/maven-3.6.0/bin:/usr/local/cmake-3.12.4/bin:/usr/local/clang-7.0.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/home/travis/.rvm/bin:/home/travis/.phpenv/bin:/opt/pyenv/bin:/home/travis/.yarn/bin',
#  'activity.2.system.environment.SHELL': '/bin/bash',
#  'activity.2.system.environment.USER': 'travis',
#  'activity.2.system.eventio_version': '1.0.1',
#  'activity.2.system.executable': '/home/travis/virtualenv/python3.8.0/bin/python',
#  'activity.2.system.platform.architecture_bits': '64bit',
#  'activity.2.system.platform.architecture_linkage': 'ELF',
#  'activity.2.system.platform.boot_time': '2020-04-13T17:33:06.000',
#  'activity.2.system.platform.libcver': ('glibc', '2.23'),
#  'activity.2.system.platform.machine': 'x86_64',
#  'activity.2.system.platform.node': 'travis-job-742a6a54-15f7-4367-9191-9a26e20b992b',
#  'activity.2.system.platform.num_cpus': 2,
#  'activity.2.system.platform.processor': 'x86_64',
#  'activity.2.system.platform.release': '4.15.0-1028-gcp',
#  'activity.2.system.platform.system': 'Linux',
#  'activity.2.system.platform.version': '#29~16.04.1-Ubuntu SMP Tue Feb 12 '
#                                        '16:31:10 UTC 2019',
#  'activity.2.system.pyhessio_version': '2.1.1',
#  'activity.2.system.python.compiler': 'GCC 5.4.0 20160609',
#  'activity.2.system.python.implementation': 'CPython',
#  'activity.2.system.python.version': ('3', '8', '0'),
#  'activity.2.system.python.version_string': '3.8.0 (default, Oct 15 2019, '
#                                             '17:49:23) \n'
#                                             '[GCC 5.4.0 20160609]',
#  'activity.2.system.start_time_utc': '2020-04-13T17:41:22.586'}
